# %%
import csv
import pandas as pd

import urllib2
url = 'http://winterolympicsmedals.com/medals.csv'
response = urllib2.urlopen(url)
cr = list(csv.DictReader(response))

for row in cr:
    print row
# Out:
# {'Discipline': 'Figure skating', 'City': 'Chamonix', 'Event gender': 'M', 'NOC': 'AUT', 'Year': '1924', 'Sport': 'Skating', 'Medal': 'Silver', 'Event': 'individual'}
# {'Discipline': 'Figure skating', 'City': 'Chamonix', 'Event gender': 'W', 'NOC': 'AUT', 'Year': '1924', 'Sport': 'Skating', 'Medal': 'Gold', 'Event': 'individual'}
# {'Discipline': 'Figure skating', 'City': 'Chamonix', 'Event gender': 'X', 'NOC': 'AUT', 'Year': '1924', 'Sport': 'Skating', 'Medal': 'Gold', 'Event': 'pairs'}
# {'Discipline': 'Bobsleigh', 'City': 'Chamonix', 'Event gender': 'M', 'NOC': 'BEL', 'Year': '1924', 'Sport': 'Bobsleigh', 'Medal': 'Bronze', 'Event': 'four-man'}
# {'Discipline': 'Ice Hockey', 'City': 'Chamonix', 'Event gender': 'M', 'NOC': 'CAN', 'Year': '1924', 'Sport': 'Ice Hockey', 'Medal': 'Gold', 'Event': 'ice hockey'}
# {'Discipline': 'Biathlon', 'City': 'Chamonix', 'Event gender': 'M', 'NOC': 'FIN', 'Year': '1924', 'Sport': 'Biathlon', 'Medal': 'Silver', 'Event': 'military patrol'}
# ...

# %%
cr[0].keys()
# Out:
# ['Discipline',
#  'City',
#  'Event gender',
#  'NOC',
#  'Year',
#  'Sport',
#  'Medal',
#  'Event']

# %%
len(cr)
# Out:
# 2311

# %%
sports=set(d['City'] for d in cr)
sports
# Out:
# {'Albertville',
#  'Calgary',
#  'Chamonix',
#  "Cortina d'Ampezzo",
#  'Garmisch-Partenkirchen',
#  'Grenoble',
#  'Innsbruck',
#  'Lake Placid',
#  'Lillehammer',
#  'Nagano',
#  'Oslo',
#  'Salt Lake City',
#  'Sapporo',
#  'Sarajevo',
#  'Squaw Valley',
#  'St. Moritz',
#  'Turin'}

# %%
sports=set(d['Sport'] for d in cr)
sports
# Out:
# {'Biathlon', 'Bobsleigh', 'Curling', 'Ice Hockey', 'Luge', 'Skating', 'Skiing'}

# %%
s=pd.Series(cr)
s
# Out:
# 0       {u'Discipline': u'Figure skating', u'City': u'...
# 1       {u'Discipline': u'Figure skating', u'City': u'...
# 2       {u'Discipline': u'Figure skating', u'City': u'...
# 3       {u'Discipline': u'Bobsleigh', u'City': u'Chamo...
# 4       {u'Discipline': u'Ice Hockey', u'City': u'Cham...
# 5       {u'Discipline': u'Biathlon', u'City': u'Chamon...
# 6       {u'Discipline': u'Figure skating', u'City': u'...
# 7       {u'Discipline': u'Speed skating', u'City': u'C...
# 8       {u'Discipline': u'Speed skating', u'City': u'C...
# 9       {u'Discipline': u'Speed skating', u'City': u'C...
# 10      {u'Discipline': u'Speed skating', u'City': u'C...
# 11      {u'Discipline': u'Speed skating', u'City': u'C...
# 12      {u'Discipline': u'Speed skating', u'City': u'C...
# 13      {u'Discipline': u'Speed skating', u'City': u'C...
# 14      {u'Discipline': u'Speed skating', u'City': u'C...
# 15      {u'Discipline': u'Cross Country S', u'City': u...
# ...

# %%
s[4]
# Out:
# {'City': 'Chamonix',
#  'Discipline': 'Ice Hockey',
#  'Event': 'ice hockey',
#  'Event gender': 'M',
#  'Medal': 'Gold',
#  'NOC': 'CAN',
#  'Sport': 'Ice Hockey',
#  'Year': '1924'}

# %%
 #DataFrame

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'A',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'B',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'C',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#          Cost Item Purchased Name
# Store 1  22.5       Dog Food    A
# Store 1   2.5   Kitty Litter    B
# Store 2   5.0      Bird Seed    C

# %%
df.loc['Store 2']
# Out:
# Cost                      5
# Item Purchased    Bird Seed
# Name                      C
# Name: Store 2, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
copy = df.copy()
copy = copy.drop('Store 1')
copy
# Out:
#          Cost Item Purchased Name
# Store 2   5.0      Bird Seed    C

# %%
del copy['Name']
copy
# Out:
#          Cost Item Purchased
# Store 2   5.0      Bird Seed

# %%
#Dataframe Indexing

# %%
df['Sport']='Skating'

# %%
cr[0:3]
# Out:
# [{'City': 'Chamonix',
#   'Discipline': 'Figure skating',
#   'Event': 'individual',
#   'Event gender': 'M',
#   'Medal': 'Silver',
#   'NOC': 'AUT',
#   'Sport': 'Skating',
#   'Year': '1924'},
#  {'City': 'Chamonix',
#   'Discipline': 'Figure skating',
#   'Event': 'individual',
#   'Event gender': 'W',
#   'Medal': 'Gold',
#   'NOC': 'AUT',
#   'Sport': 'Skating',
#   'Year': '1924'},
#  {'City': 'Chamonix',
#   'Discipline': 'Figure skating',
#   'Event': 'pairs',
#   'Event gender': 'X',
#   'Medal': 'Gold',
#   'NOC': 'AUT',
#   'Sport': 'Skating',
#   'Year': '1924'}]

# %%
df = pd.read_csv('http://winterolympicsmedals.com/medals.csv')
df.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
sport=df.where(df['Sport']=='Skating')
sport.head()
# Out:
#    Year      City    Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix  Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix  Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix  Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix  Skating       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Skating      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
#Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %%
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0), 
                   'B': np.random.randn(365).cumsum(0) + 20,
                   'C': np.random.randn(365).cumsum(0) - 20}, 
                  index=pd.date_range('1/1/2017', periods=365))
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot('A','B', kind = 'scatter');
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot.box();
# Out:
# <img src="data:image/png;base64,...">

# %%
#pandas tools

# %%
pd.tools.plotting.scatter_matrix(df);
# Out:
# <img src="data:image/png;base64,...">

# %%
winterPlot = pd.read_csv('http://winterolympicsmedals.com/medals.csv')
winterPlot.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
pd.tools.plotting.scatter_matrix(winterPlot);
# Out:
# <img src="data:image/png;base64,...">

# %%
#Subplot

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

plt.subplot?

# %%
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 2, 1)

linear_data = np.array([1,2,3,4,5,6,7,8])

plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,...">

# %%
exponential_data = linear_data**2 

# subplot with 1 row, 2 columns, and current axis is 2nd subplot axes
plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')

# %%
plt.subplot(1, 2, 1)
plt.plot(exponential_data, '-x')

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,...">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,...">
